# %%
# Import library
import pandas as pd
import numpy as np
import os, random, warnings, gc, psutil, datetime
from tqdm import tqdm_notebook, tqdm

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GroupKFold, StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from math import sqrt

import lightgbm as lgbm
from catboost import CatBoostRegressor

from glob import glob
from IPython.display import display

import seaborn as sns
import matplotlib.pyplot as plt

# Set options
pd.set_option('max_columns',500)
pd.set_option('max_rows',500)
pd.options.display.max_colwidth = 300

warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set_palette('bright')

# %%
def seed_everything(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    
seed_everything()

# %%
train = pd.read_pickle('../Create_Features/preprocessed_train2.pickle')
test = pd.read_pickle('../Create_Features/preprocessed_test2.pickle')

# %%
n_trn = 415423
target_col = '18~20_ride'

# %%
train.tail()
# Out:
#         18~20_ride bus_route_id  in_out  latitude  longitude station_code  \
# 415418         0.0          630       0  33.41437  126.26336         1044
# 415419         0.0          630       0  33.49946  126.51479         1433
# 415420         0.0          630       0  33.23100  126.26273         2146
# 415421         0.0          630       0  33.46483  126.31870         3040
# 415422         0.0          630       0  33.24873  126.50799         3599
#
#        dayofweek  weekend  ride_total  takeoff_total  ride_go_to_work  \
# 415418         0        0         4.0            0.0              0.0
# 415419         0        0         4.0            0.0              0.0
# 415420         0        0         0.0            1.0              0.0
# 415421         0        0         1.0            0.0              0.0
# 415422         0        0         0.0            4.0              0.0
#
#         takeoff_go_to_work  dis_jejusi  dis_seoquipo  \
# 415418                 0.0   25.950139     32.385460
# 415419                 0.0    0.754801     26.927069
# 415420                 1.0   38.482046     27.717482
# 415421                 0.0   19.380000     31.873252
# 415422                 4.0   27.987818      4.828453
#
#        bus_route_id_station_code bus_route_id_station_code_weekend  \
# 415418                     31002                             53650
# 415419                     31003                             53652
# 415420                     31005                             53656
# 415421                     31012                             53666
# 415422                     31014                             53670
#
#         date_fq_enc  station_code_fq_enc  bus_route_id_fq_enc  \
# 415418        15884                  725                  268
# 415419        15884                 1109                  268
# 415420        15884                  295                  268
# 415421        15884                  185                  268
# 415422        15884                  699                  268
#
#         bus_route_id_station_code_fq_enc  date_bus_route_id_fq_enc  \
# 415418                                39                         9
# 415419                                33                         9
# 415420                                11                         9
# 415421                                 6                         9
# 415422                                37                         9
#
#         date_station_code_fq_enc  date_bus_route_id_station_code_fq_enc  \
# 415418                        17                                      1
# 415419                        23                                      1
# 415420                         9                                      1
# 415421                         5                                      1
# 415422                        15                                      1
#
#         7~8_ride_date_mean  7~8_ride_date_bus_route_id_mean  \
# 415418            1.032108                              0.0
# 415419            1.032108                              0.0
# 415420            1.032108                              0.0
# 415421            1.032108                              0.0
# 415422            1.032108                              0.0
#
#         8~9_ride_date_mean  8~9_ride_date_bus_route_id_mean  \
# 415418            0.988353                              0.0
# 415419            0.988353                              0.0
# 415420            0.988353                              0.0
# 415421            0.988353                              0.0
# 415422            0.988353                              0.0
#
#         9~10_ride_date_mean  9~10_ride_date_bus_route_id_mean  \
# 415418             0.743075                               0.0
# 415419             0.743075                               0.0
# 415420             0.743075                               0.0
# 415421             0.743075                               0.0
# 415422             0.743075                               0.0
#
#         station_sequence  station_reverse_sequence  weekday  \
# 415418                 5                         5        0
# 415419                 6                         4        0
# 415420                 7                         3        0
# 415421                 8                         2        0
# 415422                 9                         1        0
#
#         is_national_holiday  getin_total  morning_getin  morning_takeoff  \
# 415418                    0          4.0            4.0              0.0
# 415419                    0          4.0            4.0              0.0
# 415420                    0          0.0            0.0              1.0
# 415421                    0          1.0            1.0              0.0
# 415422                    0          0.0            0.0              4.0
#
#         noon_getin  noon_takeoff  station_morning_getin_sum  \
# 415418         0.0           0.0                       52.0
# 415419         0.0           0.0                      567.0
# 415420         0.0           0.0                       11.0
# 415421         0.0           0.0                       11.0
# 415422         0.0           0.0                        0.0
#
#         station_morning_takeoff_sum  bus_route_getin_sum  \
# 415418                         81.0                 10.0
# 415419                          7.0                 10.0
# 415420                          4.0                 10.0
# 415421                          9.0                 10.0
# 415422                         38.0                 10.0
#
#         bus_route_takeoff_sum  station_morning_getin_mean  \
# 415418                    8.0                    3.058824
# 415419                    8.0                   24.652174
# 415420                    8.0                    1.222222
# 415421                    8.0                    2.200000
# 415422                    8.0                    0.000000
#
#         station_morning_takeoff_mean  bus_route_getin_mean  \
# 415418                      4.764706              1.111111
# 415419                      0.304348              1.111111
# 415420                      0.444444              1.111111
# 415421                      1.800000              1.111111
# 415422                      2.533333              1.111111
#
#         bus_route_takeoff_mean kmeans1 kmeans2  regular_commuter_count  \
# 415418                0.888889      48       6                    94.0
# 415419                0.888889      65      38                   627.0
# 415420                0.888889      12       6                     5.0
# 415421                0.888889      45       6                     9.0
# 415422                0.888889      12       6                     NaN
#
#         afternoon_takeoff  next_bus_time_diff  getin_user_count1_morning  \
# 415418                0.0                 NaN                       24.0
# 415419                0.0                 NaN                      490.0
# 415420                0.0                 NaN                        9.0
# 415421                0.0                 NaN                       12.0
# 415422                0.0                 NaN                        1.0
#
#         getin_user_count2_morning  takeoff_user_count1_noon  \
# 415418                        NaN                      38.0
# 415419                        1.0                       NaN
# 415420                        1.0                       1.0
# 415421                        NaN                      11.0
# 415422                        NaN                      32.0
#
#         takeoff_user_count2_noon  hourly_rain  prev_daily_rain  hourly_cloud  \
# 415418                       NaN          0.0              5.2            76
# 415419                       NaN          0.0              5.2            76
# 415420                       NaN          0.0              5.2            76
# 415421                       NaN          0.0              5.2            76
# 415422                       NaN          0.0              5.2            76
#
#        latlong_second  total_population  man_population  woman_population  \
# 415418           1692           25003.0         13337.0           11666.0
# 415419           2626           14906.0          7541.0            7365.0
# 415420             55           23094.0         11431.0           11663.0
# 415421           2070           36550.0         18902.0           17648.0
# 415422            212           14156.0          7119.0            7037.0
#
#         avg_time_diff  passengers_in  passengers_out  latitude_rank  \
# 415418    1426.345450     130.434783      113.413043       219468.0
# 415419    3103.390585     806.760870       17.782609       466717.5
# 415420    3005.568831      11.195652        2.700000         9006.0
# 415421    1475.961464      13.911111       17.130435       276473.0
# 415422    2554.831081      21.277778       97.043478        46547.0
#
#         longitude_rank  current_day_national_plane  \
# 415418         25901.0                       61516
# 415419        269985.0                       61516
# 415420         25388.0                       61516
# 415421         48222.0                       61516
# 415422        244837.0                       61516
#
#         current_day_international_plane   prev_day_national_plane  \
# 415418                             5358                     69338
# 415419                             5358                     69338
# 415420                             5358                     69338
# 415421                             5358                     69338
# 415422                             5358                     69338
#
#         prev_day_international_plane
# 415418                          6402
# 415419                          6402
# 415420                          6402
# 415421                          6402
# 415422                          6402

# %%
# Before modeling
train_set = train.drop(target_col,1)
test_set = test.drop(target_col,1)

train_label = train[target_col]
test_label = test[target_col]

# %%
# Basic LGBM Model
n_splits= 5
NUM_BOOST_ROUND = 100000
SEED = 1993
lgbm_param = {'objective':'rmse',
              'boosting_type': 'gbdt',
              'random_state':1993,
              'learning_rate':0.01,
              'subsample':0.7,
              'tree_learner': 'serial',
              'colsample_bytree':0.78,
              'early_stopping_rounds':50,
              'subsample_freq': 1,
              'reg_lambda':7,
              'reg_alpha': 5,
              'num_leaves': 96,
              'seed' : SEED
            }

# %%
# StractifiedKfold & bus_route_id
split_col = 'bus_route_id'
len_seeds = 5

outer_stractified_busroute_oof_train = np.zeros( train.shape[0] )
outer_stractified_busroute_oof_test = np.zeros( test.shape[0] )

for _ in tqdm_notebook(range(len_seeds)):
    
    seed = random.randint(1, 100000)
    
    cv_list = []

    oof_train = np.zeros( train.shape[0] )
    final_test = np.zeros( test.shape[0] )

    kfolds = StratifiedKFold(n_splits = n_splits, shuffle=True, random_state=seed )

    for ind, (trn_ind, val_ind) in tqdm_notebook( enumerate(kfolds.split(train_set, train_set[split_col])) ):

        X_train, y_train = train_set.iloc[trn_ind], train_label[trn_ind]
        X_valid, y_valid = train_set.iloc[val_ind], train_label[val_ind]
        
        dtrain = lgbm.Dataset( X_train, y_train )
        dvalid = lgbm.Dataset( X_valid, y_valid ,reference=dtrain)
        
        lgbm_param['seed'] = seed

        model = lgbm.train(lgbm_param , dtrain, NUM_BOOST_ROUND, valid_sets=(dtrain, dvalid), valid_names=('train','valid'), 
                            categorical_feature=['bus_route_id','station_code','weekday',\
                                                                'kmeans1','kmeans2',
                                                                ] ,
                           verbose_eval= 100)

        valid_pred = model.predict(X_valid)
        test_pred  = model.predict(test_set)

        oof_train[val_ind] += valid_pred
        final_test += test_pred

        cv_list.append( sqrt(mean_squared_error(y_valid, valid_pred)) )

        print('='*80)

    final_test /= n_splits

    print(f"Average CV : {np.mean(cv_list)}")
    print(f"RMSE for OOF: {sqrt(mean_squared_error(train_label, oof_train))}")
    
    outer_stractified_busroute_oof_train += oof_train
    outer_stractified_busroute_oof_test += final_test
    
outer_stractified_busroute_oof_train /=len_seeds
outer_stractified_busroute_oof_test /= len_seeds

print(f"Overall for OOF: {sqrt(mean_squared_error(train_label, outer_stractified_busroute_oof_train))}")

# PostProcessing
outer_stractified_busroute_oof_train = [x if x>0 else 0 for x in  outer_stractified_busroute_oof_train]
outer_stractified_busroute_oof_test = [x if x>0 else 0 for x in  outer_stractified_busroute_oof_test]


print(f"RMSE for OOF: {sqrt(mean_squared_error(train_label, outer_stractified_busroute_oof_train))}")
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.89949	valid's rmse: 2.883
# [200]	train's rmse: 2.28091	valid's rmse: 2.38208
# [300]	train's rmse: 2.04022	valid's rmse: 2.24322
# [400]	train's rmse: 1.91365	valid's rmse: 2.19713
# [500]	train's rmse: 1.8299	valid's rmse: 2.17688
# [600]	train's rmse: 1.76711	valid's rmse: 2.16976
# [700]	train's rmse: 1.7171	valid's rmse: 2.16365
# [800]	train's rmse: 1.6753	valid's rmse: 2.16161
# [900]	train's rmse: 1.6376	valid's rmse: 2.15879
# [1000]	train's rmse: 1.60355	valid's rmse: 2.15586
# [1100]	train's rmse: 1.57274	valid's rmse: 2.15388
# [1200]	train's rmse: 1.54453	valid's rmse: 2.15176
# [1300]	train's rmse: 1.51818	valid's rmse: 2.14952
# [1400]	train's rmse: 1.494	valid's rmse: 2.1486
# [1500]	train's rmse: 1.47151	valid's rmse: 2.147
# Early stopping, best iteration is:
# [1545]	train's rmse: 1.46203	valid's rmse: 2.14606
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.9065	valid's rmse: 2.87764
# [200]	train's rmse: 2.28513	valid's rmse: 2.3711
# [300]	train's rmse: 2.04915	valid's rmse: 2.21272
# [400]	train's rmse: 1.92114	valid's rmse: 2.15022
# [500]	train's rmse: 1.83634	valid's rmse: 2.12075
# [600]	train's rmse: 1.77271	valid's rmse: 2.10514
# [700]	train's rmse: 1.72206	valid's rmse: 2.09619
# [800]	train's rmse: 1.67818	valid's rmse: 2.09009
# [900]	train's rmse: 1.63985	valid's rmse: 2.08563
# [1000]	train's rmse: 1.60485	valid's rmse: 2.08247
# [1100]	train's rmse: 1.57367	valid's rmse: 2.07916
# [1200]	train's rmse: 1.54468	valid's rmse: 2.07607
# [1300]	train's rmse: 1.51766	valid's rmse: 2.07365
# [1400]	train's rmse: 1.49365	valid's rmse: 2.07258
# [1500]	train's rmse: 1.47092	valid's rmse: 2.07094
# [1600]	train's rmse: 1.44983	valid's rmse: 2.06964
# [1700]	train's rmse: 1.42982	valid's rmse: 2.06863
# [1800]	train's rmse: 1.41107	valid's rmse: 2.06824
# [1900]	train's rmse: 1.39313	valid's rmse: 2.06735
# [2000]	train's rmse: 1.3762	valid's rmse: 2.06727
# Early stopping, best iteration is:
# [1961]	train's rmse: 1.38274	valid's rmse: 2.06702
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.89681	valid's rmse: 2.99517
# [200]	train's rmse: 2.28781	valid's rmse: 2.43501
# [300]	train's rmse: 2.05331	valid's rmse: 2.25701
# [400]	train's rmse: 1.92631	valid's rmse: 2.18447
# [500]	train's rmse: 1.84089	valid's rmse: 2.14586
# [600]	train's rmse: 1.77838	valid's rmse: 2.129
# [700]	train's rmse: 1.72745	valid's rmse: 2.11721
# [800]	train's rmse: 1.68359	valid's rmse: 2.10934
# [900]	train's rmse: 1.64483	valid's rmse: 2.10264
# [1000]	train's rmse: 1.61032	valid's rmse: 2.09769
# [1100]	train's rmse: 1.57892	valid's rmse: 2.0935
# [1200]	train's rmse: 1.55046	valid's rmse: 2.09057
# [1300]	train's rmse: 1.52427	valid's rmse: 2.08767
# [1400]	train's rmse: 1.50011	valid's rmse: 2.08605
# [1500]	train's rmse: 1.47756	valid's rmse: 2.08445
# [1600]	train's rmse: 1.45647	valid's rmse: 2.08333
# [1700]	train's rmse: 1.43653	valid's rmse: 2.08202
# [1800]	train's rmse: 1.41772	valid's rmse: 2.08136
# [1900]	train's rmse: 1.39996	valid's rmse: 2.0799
# [2000]	train's rmse: 1.3832	valid's rmse: 2.07924
# Early stopping, best iteration is:
# [1976]	train's rmse: 1.38702	valid's rmse: 2.07907
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.86018	valid's rmse: 3.12838
# [200]	train's rmse: 2.25271	valid's rmse: 2.59621
# [300]	train's rmse: 2.02113	valid's rmse: 2.42583
# [400]	train's rmse: 1.89615	valid's rmse: 2.35254
# [500]	train's rmse: 1.81401	valid's rmse: 2.31879
# [600]	train's rmse: 1.75183	valid's rmse: 2.30127
# [700]	train's rmse: 1.70262	valid's rmse: 2.29077
# [800]	train's rmse: 1.66007	valid's rmse: 2.28487
# [900]	train's rmse: 1.62235	valid's rmse: 2.27866
# [1000]	train's rmse: 1.58824	valid's rmse: 2.27257
# [1100]	train's rmse: 1.55781	valid's rmse: 2.26837
# [1200]	train's rmse: 1.53042	valid's rmse: 2.26557
# [1300]	train's rmse: 1.5049	valid's rmse: 2.26325
# [1400]	train's rmse: 1.48166	valid's rmse: 2.2611
# [1500]	train's rmse: 1.4595	valid's rmse: 2.25873
# [1600]	train's rmse: 1.43872	valid's rmse: 2.25623
# [1700]	train's rmse: 1.41934	valid's rmse: 2.25447
# [1800]	train's rmse: 1.4015	valid's rmse: 2.25254
# [1900]	train's rmse: 1.38455	valid's rmse: 2.25126
# [2000]	train's rmse: 1.36825	valid's rmse: 2.24998
# [2100]	train's rmse: 1.35306	valid's rmse: 2.24868
# [2200]	train's rmse: 1.33832	valid's rmse: 2.24701
# [2300]	train's rmse: 1.32446	valid's rmse: 2.24666
# [2400]	train's rmse: 1.31109	valid's rmse: 2.24568
# [2500]	train's rmse: 1.29821	valid's rmse: 2.24518
# [2600]	train's rmse: 1.28585	valid's rmse: 2.24456
# [2700]	train's rmse: 1.2741	valid's rmse: 2.24381
# Early stopping, best iteration is:
# [2711]	train's rmse: 1.27278	valid's rmse: 2.24374
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.88574	valid's rmse: 2.98492
# [200]	train's rmse: 2.2727	valid's rmse: 2.45747
# [300]	train's rmse: 2.03689	valid's rmse: 2.29121
# [400]	train's rmse: 1.91039	valid's rmse: 2.22647
# [500]	train's rmse: 1.82603	valid's rmse: 2.19676
# [600]	train's rmse: 1.76346	valid's rmse: 2.18053
# [700]	train's rmse: 1.71262	valid's rmse: 2.16956
# [800]	train's rmse: 1.67014	valid's rmse: 2.16172
# [900]	train's rmse: 1.63266	valid's rmse: 2.15551
# [1000]	train's rmse: 1.5982	valid's rmse: 2.15011
# [1100]	train's rmse: 1.56684	valid's rmse: 2.14689
# [1200]	train's rmse: 1.53863	valid's rmse: 2.14447
# [1300]	train's rmse: 1.51228	valid's rmse: 2.14084
# [1400]	train's rmse: 1.48862	valid's rmse: 2.13786
# [1500]	train's rmse: 1.46623	valid's rmse: 2.13576
# [1600]	train's rmse: 1.44479	valid's rmse: 2.13394
# [1700]	train's rmse: 1.42533	valid's rmse: 2.13242
# [1800]	train's rmse: 1.40684	valid's rmse: 2.13069
# [1900]	train's rmse: 1.38951	valid's rmse: 2.12958
# [2000]	train's rmse: 1.37296	valid's rmse: 2.12851
# [2100]	train's rmse: 1.35691	valid's rmse: 2.12762
# [2200]	train's rmse: 1.3418	valid's rmse: 2.12735
# Early stopping, best iteration is:
# [2174]	train's rmse: 1.34562	valid's rmse: 2.12712
# ================================================================================
#
# Average CV : 2.1326018129910755
# RMSE for OOF: 2.1334870541835667
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.92161	valid's rmse: 2.80745
# [200]	train's rmse: 2.2996	valid's rmse: 2.29905
# [300]	train's rmse: 2.06098	valid's rmse: 2.14832
# [400]	train's rmse: 1.93202	valid's rmse: 2.08983
# [500]	train's rmse: 1.84556	valid's rmse: 2.0634
# [600]	train's rmse: 1.78241	valid's rmse: 2.04875
# [700]	train's rmse: 1.73142	valid's rmse: 2.04047
# [800]	train's rmse: 1.68779	valid's rmse: 2.03558
# [900]	train's rmse: 1.64933	valid's rmse: 2.03121
# [1000]	train's rmse: 1.61448	valid's rmse: 2.02781
# [1100]	train's rmse: 1.58272	valid's rmse: 2.0242
# [1200]	train's rmse: 1.55439	valid's rmse: 2.02191
# [1300]	train's rmse: 1.52815	valid's rmse: 2.01917
# [1400]	train's rmse: 1.50436	valid's rmse: 2.0166
# [1500]	train's rmse: 1.4813	valid's rmse: 2.01535
# [1600]	train's rmse: 1.46008	valid's rmse: 2.01374
# [1700]	train's rmse: 1.44029	valid's rmse: 2.01199
# [1800]	train's rmse: 1.42121	valid's rmse: 2.01057
# [1900]	train's rmse: 1.4033	valid's rmse: 2.00995
# [2000]	train's rmse: 1.38651	valid's rmse: 2.00899
# [2100]	train's rmse: 1.37051	valid's rmse: 2.00811
# [2200]	train's rmse: 1.35533	valid's rmse: 2.00808
# Early stopping, best iteration is:
# [2150]	train's rmse: 1.36296	valid's rmse: 2.00784
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.91105	valid's rmse: 2.88577
# [200]	train's rmse: 2.29383	valid's rmse: 2.37191
# [300]	train's rmse: 2.05399	valid's rmse: 2.22049
# [400]	train's rmse: 1.92329	valid's rmse: 2.16309
# [500]	train's rmse: 1.83868	valid's rmse: 2.13638
# [600]	train's rmse: 1.77432	valid's rmse: 2.12163
# [700]	train's rmse: 1.72364	valid's rmse: 2.11178
# [800]	train's rmse: 1.67975	valid's rmse: 2.10397
# [900]	train's rmse: 1.64086	valid's rmse: 2.09868
# [1000]	train's rmse: 1.6058	valid's rmse: 2.09351
# [1100]	train's rmse: 1.57421	valid's rmse: 2.08915
# [1200]	train's rmse: 1.54597	valid's rmse: 2.08684
# [1300]	train's rmse: 1.51984	valid's rmse: 2.08372
# [1400]	train's rmse: 1.49504	valid's rmse: 2.08099
# [1500]	train's rmse: 1.47186	valid's rmse: 2.079
# [1600]	train's rmse: 1.45069	valid's rmse: 2.07655
# [1700]	train's rmse: 1.4309	valid's rmse: 2.07406
# [1800]	train's rmse: 1.41207	valid's rmse: 2.07253
# [1900]	train's rmse: 1.39416	valid's rmse: 2.07123
# [2000]	train's rmse: 1.37717	valid's rmse: 2.07017
# [2100]	train's rmse: 1.36126	valid's rmse: 2.06924
# [2200]	train's rmse: 1.34595	valid's rmse: 2.06844
# [2300]	train's rmse: 1.33131	valid's rmse: 2.0675
# [2400]	train's rmse: 1.31745	valid's rmse: 2.06705
# Early stopping, best iteration is:
# [2410]	train's rmse: 1.31619	valid's rmse: 2.06677
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.89367	valid's rmse: 3.07203
# [200]	train's rmse: 2.28642	valid's rmse: 2.49508
# [300]	train's rmse: 2.05034	valid's rmse: 2.30072
# [400]	train's rmse: 1.92206	valid's rmse: 2.21901
# [500]	train's rmse: 1.83613	valid's rmse: 2.18254
# [600]	train's rmse: 1.7748	valid's rmse: 2.1634
# [700]	train's rmse: 1.72491	valid's rmse: 2.15275
# [800]	train's rmse: 1.68124	valid's rmse: 2.14684
# [900]	train's rmse: 1.64388	valid's rmse: 2.14437
# [1000]	train's rmse: 1.61066	valid's rmse: 2.14166
# [1100]	train's rmse: 1.57986	valid's rmse: 2.13993
# [1200]	train's rmse: 1.55215	valid's rmse: 2.13725
# [1300]	train's rmse: 1.52558	valid's rmse: 2.13573
# [1400]	train's rmse: 1.50176	valid's rmse: 2.13503
# Early stopping, best iteration is:
# [1358]	train's rmse: 1.51159	valid's rmse: 2.13469
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.86247	valid's rmse: 3.05125
# [200]	train's rmse: 2.23817	valid's rmse: 2.54753
# [300]	train's rmse: 1.99823	valid's rmse: 2.40415
# [400]	train's rmse: 1.87548	valid's rmse: 2.35122
# [500]	train's rmse: 1.79397	valid's rmse: 2.32757
# [600]	train's rmse: 1.73505	valid's rmse: 2.31504
# [700]	train's rmse: 1.68689	valid's rmse: 2.30894
# [800]	train's rmse: 1.64691	valid's rmse: 2.30543
# [900]	train's rmse: 1.61093	valid's rmse: 2.30144
# [1000]	train's rmse: 1.57894	valid's rmse: 2.29728
# [1100]	train's rmse: 1.55014	valid's rmse: 2.29366
# [1200]	train's rmse: 1.5236	valid's rmse: 2.29122
# [1300]	train's rmse: 1.49897	valid's rmse: 2.28874
# [1400]	train's rmse: 1.47645	valid's rmse: 2.28733
# [1500]	train's rmse: 1.45489	valid's rmse: 2.28502
# [1600]	train's rmse: 1.43514	valid's rmse: 2.28381
# [1700]	train's rmse: 1.41618	valid's rmse: 2.2825
# [1800]	train's rmse: 1.39823	valid's rmse: 2.28061
# [1900]	train's rmse: 1.38117	valid's rmse: 2.2795
# [2000]	train's rmse: 1.36526	valid's rmse: 2.27805
# Early stopping, best iteration is:
# [2046]	train's rmse: 1.35811	valid's rmse: 2.27749
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.8676	valid's rmse: 3.07472
# [200]	train's rmse: 2.25389	valid's rmse: 2.52474
# [300]	train's rmse: 2.02102	valid's rmse: 2.36003
# [400]	train's rmse: 1.89543	valid's rmse: 2.29302
# [500]	train's rmse: 1.81286	valid's rmse: 2.26223
# [600]	train's rmse: 1.75125	valid's rmse: 2.24586
# [700]	train's rmse: 1.70244	valid's rmse: 2.23611
# [800]	train's rmse: 1.6603	valid's rmse: 2.23089
# [900]	train's rmse: 1.62289	valid's rmse: 2.22597
# [1000]	train's rmse: 1.58936	valid's rmse: 2.22167
# [1100]	train's rmse: 1.55901	valid's rmse: 2.21857
# [1200]	train's rmse: 1.53108	valid's rmse: 2.21512
# [1300]	train's rmse: 1.50597	valid's rmse: 2.21189
# [1400]	train's rmse: 1.4823	valid's rmse: 2.20954
# [1500]	train's rmse: 1.4605	valid's rmse: 2.20758
# [1600]	train's rmse: 1.43998	valid's rmse: 2.20625
# [1700]	train's rmse: 1.42072	valid's rmse: 2.20547
# Early stopping, best iteration is:
# [1660]	train's rmse: 1.42829	valid's rmse: 2.20516
# ================================================================================
#
# Average CV : 2.138392836165487
# RMSE for OOF: 2.1403688718116265
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.88858	valid's rmse: 2.97046
# [200]	train's rmse: 2.27393	valid's rmse: 2.44062
# [300]	train's rmse: 2.03551	valid's rmse: 2.28262
# [400]	train's rmse: 1.91074	valid's rmse: 2.22331
# [500]	train's rmse: 1.82769	valid's rmse: 2.19473
# [600]	train's rmse: 1.76485	valid's rmse: 2.17993
# [700]	train's rmse: 1.71372	valid's rmse: 2.17045
# [800]	train's rmse: 1.67014	valid's rmse: 2.16271
# [900]	train's rmse: 1.63177	valid's rmse: 2.15784
# [1000]	train's rmse: 1.59844	valid's rmse: 2.15423
# [1100]	train's rmse: 1.56794	valid's rmse: 2.1504
# [1200]	train's rmse: 1.53993	valid's rmse: 2.14837
# [1300]	train's rmse: 1.51364	valid's rmse: 2.14713
# [1400]	train's rmse: 1.48975	valid's rmse: 2.14633
# [1500]	train's rmse: 1.46733	valid's rmse: 2.14416
# [1600]	train's rmse: 1.44654	valid's rmse: 2.1416
# [1700]	train's rmse: 1.42721	valid's rmse: 2.13948
# [1800]	train's rmse: 1.40927	valid's rmse: 2.13869
# [1900]	train's rmse: 1.39173	valid's rmse: 2.13801
# [2000]	train's rmse: 1.37545	valid's rmse: 2.13733
# [2100]	train's rmse: 1.35961	valid's rmse: 2.13661
# [2200]	train's rmse: 1.3447	valid's rmse: 2.13587
# [2300]	train's rmse: 1.33045	valid's rmse: 2.13523
# [2400]	train's rmse: 1.31652	valid's rmse: 2.13506
# Early stopping, best iteration is:
# [2361]	train's rmse: 1.32197	valid's rmse: 2.13486
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.87114	valid's rmse: 3.04054
# [200]	train's rmse: 2.24912	valid's rmse: 2.55126
# [300]	train's rmse: 2.0119	valid's rmse: 2.40228
# [400]	train's rmse: 1.88602	valid's rmse: 2.3457
# [500]	train's rmse: 1.80281	valid's rmse: 2.31634
# [600]	train's rmse: 1.74236	valid's rmse: 2.30121
# [700]	train's rmse: 1.69297	valid's rmse: 2.29143
# [800]	train's rmse: 1.65146	valid's rmse: 2.28466
# [900]	train's rmse: 1.6148	valid's rmse: 2.27953
# [1000]	train's rmse: 1.58197	valid's rmse: 2.27521
# [1100]	train's rmse: 1.55234	valid's rmse: 2.27143
# [1200]	train's rmse: 1.52485	valid's rmse: 2.26903
# [1300]	train's rmse: 1.49965	valid's rmse: 2.2662
# [1400]	train's rmse: 1.47667	valid's rmse: 2.26422
# [1500]	train's rmse: 1.45538	valid's rmse: 2.26083
# [1600]	train's rmse: 1.43537	valid's rmse: 2.25817
# [1700]	train's rmse: 1.41602	valid's rmse: 2.25687
# [1800]	train's rmse: 1.39768	valid's rmse: 2.25587
# [1900]	train's rmse: 1.38081	valid's rmse: 2.25415
# [2000]	train's rmse: 1.36464	valid's rmse: 2.25302
# [2100]	train's rmse: 1.3495	valid's rmse: 2.25209
# [2200]	train's rmse: 1.33476	valid's rmse: 2.25041
# [2300]	train's rmse: 1.32114	valid's rmse: 2.24902
# [2400]	train's rmse: 1.30798	valid's rmse: 2.24798
# [2500]	train's rmse: 1.2951	valid's rmse: 2.24722
# [2600]	train's rmse: 1.28281	valid's rmse: 2.24625
# Early stopping, best iteration is:
# [2647]	train's rmse: 1.27713	valid's rmse: 2.24578
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.91003	valid's rmse: 2.88635
# [200]	train's rmse: 2.29144	valid's rmse: 2.36098
# [300]	train's rmse: 2.05241	valid's rmse: 2.20805
# [400]	train's rmse: 1.92463	valid's rmse: 2.14987
# [500]	train's rmse: 1.83832	valid's rmse: 2.12475
# [600]	train's rmse: 1.77585	valid's rmse: 2.11409
# [700]	train's rmse: 1.72371	valid's rmse: 2.10682
# [800]	train's rmse: 1.68036	valid's rmse: 2.10113
# [900]	train's rmse: 1.64237	valid's rmse: 2.09756
# [1000]	train's rmse: 1.6088	valid's rmse: 2.09453
# [1100]	train's rmse: 1.57822	valid's rmse: 2.09131
# [1200]	train's rmse: 1.55002	valid's rmse: 2.08908
# [1300]	train's rmse: 1.52376	valid's rmse: 2.08748
# [1400]	train's rmse: 1.49962	valid's rmse: 2.08588
# [1500]	train's rmse: 1.47707	valid's rmse: 2.08456
# [1600]	train's rmse: 1.45603	valid's rmse: 2.08366
# Early stopping, best iteration is:
# [1618]	train's rmse: 1.45225	valid's rmse: 2.0834
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.90245	valid's rmse: 2.9216
# [200]	train's rmse: 2.28579	valid's rmse: 2.3793
# [300]	train's rmse: 2.04793	valid's rmse: 2.21517
# [400]	train's rmse: 1.92151	valid's rmse: 2.14859
# [500]	train's rmse: 1.83692	valid's rmse: 2.11792
# [600]	train's rmse: 1.77349	valid's rmse: 2.10175
# [700]	train's rmse: 1.7215	valid's rmse: 2.09092
# [800]	train's rmse: 1.67762	valid's rmse: 2.08485
# [900]	train's rmse: 1.63936	valid's rmse: 2.08121
# [1000]	train's rmse: 1.6052	valid's rmse: 2.07772
# [1100]	train's rmse: 1.57492	valid's rmse: 2.07594
# [1200]	train's rmse: 1.54662	valid's rmse: 2.07522
# [1300]	train's rmse: 1.52054	valid's rmse: 2.07347
# [1400]	train's rmse: 1.4965	valid's rmse: 2.07209
# [1500]	train's rmse: 1.47414	valid's rmse: 2.07083
# [1600]	train's rmse: 1.45286	valid's rmse: 2.06918
# [1700]	train's rmse: 1.43295	valid's rmse: 2.06875
# Early stopping, best iteration is:
# [1666]	train's rmse: 1.43958	valid's rmse: 2.06838
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.87938	valid's rmse: 3.04811
# [200]	train's rmse: 2.27205	valid's rmse: 2.4954
# [300]	train's rmse: 2.03608	valid's rmse: 2.31372
# [400]	train's rmse: 1.91196	valid's rmse: 2.23935
# [500]	train's rmse: 1.82885	valid's rmse: 2.20195
# [600]	train's rmse: 1.76837	valid's rmse: 2.18638
# [700]	train's rmse: 1.71839	valid's rmse: 2.1742
# [800]	train's rmse: 1.67571	valid's rmse: 2.16578
# [900]	train's rmse: 1.63755	valid's rmse: 2.15914
# [1000]	train's rmse: 1.60365	valid's rmse: 2.15653
# [1100]	train's rmse: 1.57333	valid's rmse: 2.15358
# [1200]	train's rmse: 1.54568	valid's rmse: 2.15177
# [1300]	train's rmse: 1.52015	valid's rmse: 2.14799
# [1400]	train's rmse: 1.49613	valid's rmse: 2.14637
# [1500]	train's rmse: 1.4736	valid's rmse: 2.144
# [1600]	train's rmse: 1.45296	valid's rmse: 2.14257
# [1700]	train's rmse: 1.43327	valid's rmse: 2.14122
# [1800]	train's rmse: 1.41486	valid's rmse: 2.13976
# [1900]	train's rmse: 1.39745	valid's rmse: 2.13805
# [2000]	train's rmse: 1.38081	valid's rmse: 2.13715
# [2100]	train's rmse: 1.36482	valid's rmse: 2.13472
# [2200]	train's rmse: 1.34943	valid's rmse: 2.13401
# [2300]	train's rmse: 1.3351	valid's rmse: 2.13298
# Early stopping, best iteration is:
# [2293]	train's rmse: 1.33613	valid's rmse: 2.13293
# ================================================================================
#
# Average CV : 2.133070770498717
# RMSE for OOF: 2.134031209565441
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.94344	valid's rmse: 2.71145
# [200]	train's rmse: 2.31482	valid's rmse: 2.20626
# [300]	train's rmse: 2.07431	valid's rmse: 2.06817
# [400]	train's rmse: 1.94485	valid's rmse: 2.01539
# [500]	train's rmse: 1.85642	valid's rmse: 1.99351
# [600]	train's rmse: 1.79203	valid's rmse: 1.98786
# [700]	train's rmse: 1.74003	valid's rmse: 1.98459
# [800]	train's rmse: 1.69534	valid's rmse: 1.98274
# [900]	train's rmse: 1.65556	valid's rmse: 1.98056
# [1000]	train's rmse: 1.62041	valid's rmse: 1.9793
# [1100]	train's rmse: 1.5889	valid's rmse: 1.97812
# [1200]	train's rmse: 1.56001	valid's rmse: 1.97658
# [1300]	train's rmse: 1.53343	valid's rmse: 1.97493
# Early stopping, best iteration is:
# [1296]	train's rmse: 1.53452	valid's rmse: 1.97479
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.89751	valid's rmse: 3.02038
# [200]	train's rmse: 2.27358	valid's rmse: 2.48953
# [300]	train's rmse: 2.03471	valid's rmse: 2.33011
# [400]	train's rmse: 1.90808	valid's rmse: 2.26783
# [500]	train's rmse: 1.82361	valid's rmse: 2.24001
# [600]	train's rmse: 1.76229	valid's rmse: 2.22501
# [700]	train's rmse: 1.71186	valid's rmse: 2.21415
# [800]	train's rmse: 1.67026	valid's rmse: 2.20706
# [900]	train's rmse: 1.63251	valid's rmse: 2.2015
# [1000]	train's rmse: 1.59904	valid's rmse: 2.19806
# [1100]	train's rmse: 1.56896	valid's rmse: 2.19515
# [1200]	train's rmse: 1.54155	valid's rmse: 2.19251
# [1300]	train's rmse: 1.51584	valid's rmse: 2.18913
# [1400]	train's rmse: 1.4915	valid's rmse: 2.18656
# [1500]	train's rmse: 1.46943	valid's rmse: 2.18464
# [1600]	train's rmse: 1.44868	valid's rmse: 2.18286
# [1700]	train's rmse: 1.42937	valid's rmse: 2.18103
# [1800]	train's rmse: 1.41092	valid's rmse: 2.17964
# [1900]	train's rmse: 1.39325	valid's rmse: 2.17729
# [2000]	train's rmse: 1.377	valid's rmse: 2.1761
# [2100]	train's rmse: 1.36151	valid's rmse: 2.17417
# [2200]	train's rmse: 1.34699	valid's rmse: 2.17364
# [2300]	train's rmse: 1.33288	valid's rmse: 2.17202
# [2400]	train's rmse: 1.31915	valid's rmse: 2.17076
# Early stopping, best iteration is:
# [2443]	train's rmse: 1.31346	valid's rmse: 2.17014
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.8609	valid's rmse: 3.22154
# [200]	train's rmse: 2.25706	valid's rmse: 2.63013
# [300]	train's rmse: 2.02477	valid's rmse: 2.43264
# [400]	train's rmse: 1.90106	valid's rmse: 2.35191
# [500]	train's rmse: 1.8179	valid's rmse: 2.30711
# [600]	train's rmse: 1.75648	valid's rmse: 2.28466
# [700]	train's rmse: 1.70669	valid's rmse: 2.27073
# [800]	train's rmse: 1.66434	valid's rmse: 2.26151
# [900]	train's rmse: 1.62735	valid's rmse: 2.25391
# [1000]	train's rmse: 1.59487	valid's rmse: 2.2485
# [1100]	train's rmse: 1.56451	valid's rmse: 2.24508
# [1200]	train's rmse: 1.5368	valid's rmse: 2.24158
# [1300]	train's rmse: 1.51096	valid's rmse: 2.2379
# [1400]	train's rmse: 1.48717	valid's rmse: 2.23454
# [1500]	train's rmse: 1.46539	valid's rmse: 2.23176
# [1600]	train's rmse: 1.44495	valid's rmse: 2.23089
# [1700]	train's rmse: 1.42554	valid's rmse: 2.22887
# [1800]	train's rmse: 1.40739	valid's rmse: 2.22725
# [1900]	train's rmse: 1.39008	valid's rmse: 2.22587
# [2000]	train's rmse: 1.37388	valid's rmse: 2.22477
# [2100]	train's rmse: 1.35814	valid's rmse: 2.22295
# [2200]	train's rmse: 1.34329	valid's rmse: 2.22223
# [2300]	train's rmse: 1.32902	valid's rmse: 2.22169
# [2400]	train's rmse: 1.31529	valid's rmse: 2.22055
# [2500]	train's rmse: 1.30231	valid's rmse: 2.21903
# [2600]	train's rmse: 1.28983	valid's rmse: 2.21838
# Early stopping, best iteration is:
# [2589]	train's rmse: 1.29117	valid's rmse: 2.21829
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.88564	valid's rmse: 3.05268
# [200]	train's rmse: 2.25856	valid's rmse: 2.57459
# [300]	train's rmse: 2.02117	valid's rmse: 2.41162
# [400]	train's rmse: 1.89611	valid's rmse: 2.34275
# [500]	train's rmse: 1.81125	valid's rmse: 2.30781
# [600]	train's rmse: 1.75088	valid's rmse: 2.29108
# [700]	train's rmse: 1.70166	valid's rmse: 2.28171
# [800]	train's rmse: 1.65973	valid's rmse: 2.27415
# [900]	train's rmse: 1.62258	valid's rmse: 2.26892
# [1000]	train's rmse: 1.58877	valid's rmse: 2.26383
# [1100]	train's rmse: 1.55875	valid's rmse: 2.25885
# [1200]	train's rmse: 1.53147	valid's rmse: 2.25618
# [1300]	train's rmse: 1.50614	valid's rmse: 2.25458
# [1400]	train's rmse: 1.48251	valid's rmse: 2.25143
# [1500]	train's rmse: 1.46083	valid's rmse: 2.24873
# [1600]	train's rmse: 1.4404	valid's rmse: 2.24687
# [1700]	train's rmse: 1.42115	valid's rmse: 2.24515
# [1800]	train's rmse: 1.40309	valid's rmse: 2.24353
# [1900]	train's rmse: 1.38617	valid's rmse: 2.24244
# [2000]	train's rmse: 1.36975	valid's rmse: 2.24175
# [2100]	train's rmse: 1.35446	valid's rmse: 2.24067
# [2200]	train's rmse: 1.33978	valid's rmse: 2.23895
# [2300]	train's rmse: 1.32595	valid's rmse: 2.23761
# [2400]	train's rmse: 1.31259	valid's rmse: 2.23675
# [2500]	train's rmse: 1.29958	valid's rmse: 2.2352
# [2600]	train's rmse: 1.28704	valid's rmse: 2.23425
# [2700]	train's rmse: 1.27537	valid's rmse: 2.23347
# [2800]	train's rmse: 1.26394	valid's rmse: 2.23259
# [2900]	train's rmse: 1.25304	valid's rmse: 2.23232
# [3000]	train's rmse: 1.2424	valid's rmse: 2.23208
# [3100]	train's rmse: 1.23211	valid's rmse: 2.23152
# [3200]	train's rmse: 1.22217	valid's rmse: 2.231
# Early stopping, best iteration is:
# [3173]	train's rmse: 1.22477	valid's rmse: 2.23085
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.911	valid's rmse: 2.91138
# [200]	train's rmse: 2.29628	valid's rmse: 2.35268
# [300]	train's rmse: 2.05458	valid's rmse: 2.20228
# [400]	train's rmse: 1.92439	valid's rmse: 2.15301
# [500]	train's rmse: 1.83807	valid's rmse: 2.13091
# [600]	train's rmse: 1.7747	valid's rmse: 2.12036
# [700]	train's rmse: 1.72256	valid's rmse: 2.11525
# [800]	train's rmse: 1.67872	valid's rmse: 2.10883
# [900]	train's rmse: 1.64051	valid's rmse: 2.10569
# [1000]	train's rmse: 1.60583	valid's rmse: 2.10227
# [1100]	train's rmse: 1.57394	valid's rmse: 2.10039
# [1200]	train's rmse: 1.54527	valid's rmse: 2.09873
# [1300]	train's rmse: 1.51926	valid's rmse: 2.09674
# [1400]	train's rmse: 1.49466	valid's rmse: 2.09511
# [1500]	train's rmse: 1.47222	valid's rmse: 2.09419
# [1600]	train's rmse: 1.45037	valid's rmse: 2.09182
# [1700]	train's rmse: 1.4301	valid's rmse: 2.09154
# Early stopping, best iteration is:
# [1662]	train's rmse: 1.43749	valid's rmse: 2.09125
# ================================================================================
#
# Average CV : 2.1370638039336742
# RMSE for OOF: 2.1390786454668893
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.87543	valid's rmse: 3.06383
# [200]	train's rmse: 2.2569	valid's rmse: 2.54574
# [300]	train's rmse: 2.02507	valid's rmse: 2.38055
# [400]	train's rmse: 1.89937	valid's rmse: 2.31111
# [500]	train's rmse: 1.81714	valid's rmse: 2.27683
# [600]	train's rmse: 1.75554	valid's rmse: 2.25638
# [700]	train's rmse: 1.70569	valid's rmse: 2.24458
# [800]	train's rmse: 1.66302	valid's rmse: 2.23732
# [900]	train's rmse: 1.62559	valid's rmse: 2.22962
# [1000]	train's rmse: 1.59282	valid's rmse: 2.22581
# [1100]	train's rmse: 1.56167	valid's rmse: 2.22158
# [1200]	train's rmse: 1.53412	valid's rmse: 2.21963
# [1300]	train's rmse: 1.50831	valid's rmse: 2.21837
# Early stopping, best iteration is:
# [1334]	train's rmse: 1.50003	valid's rmse: 2.21735
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.90527	valid's rmse: 2.97531
# [200]	train's rmse: 2.28406	valid's rmse: 2.42707
# [300]	train's rmse: 2.04684	valid's rmse: 2.26915
# [400]	train's rmse: 1.9176	valid's rmse: 2.21003
# [500]	train's rmse: 1.83371	valid's rmse: 2.18426
# [600]	train's rmse: 1.7714	valid's rmse: 2.17045
# [700]	train's rmse: 1.72041	valid's rmse: 2.15904
# [800]	train's rmse: 1.67636	valid's rmse: 2.15242
# [900]	train's rmse: 1.63761	valid's rmse: 2.14654
# [1000]	train's rmse: 1.6026	valid's rmse: 2.14305
# [1100]	train's rmse: 1.5715	valid's rmse: 2.13921
# [1200]	train's rmse: 1.54311	valid's rmse: 2.13701
# [1300]	train's rmse: 1.5164	valid's rmse: 2.13649
# [1400]	train's rmse: 1.49234	valid's rmse: 2.1341
# [1500]	train's rmse: 1.46935	valid's rmse: 2.13222
# [1600]	train's rmse: 1.44839	valid's rmse: 2.13117
# [1700]	train's rmse: 1.42906	valid's rmse: 2.12945
# [1800]	train's rmse: 1.41046	valid's rmse: 2.12891
# Early stopping, best iteration is:
# [1759]	train's rmse: 1.41799	valid's rmse: 2.12862
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.88777	valid's rmse: 2.95588
# [200]	train's rmse: 2.271	valid's rmse: 2.4295
# [300]	train's rmse: 2.03472	valid's rmse: 2.27653
# [400]	train's rmse: 1.90636	valid's rmse: 2.21692
# [500]	train's rmse: 1.82395	valid's rmse: 2.18856
# [600]	train's rmse: 1.7623	valid's rmse: 2.17468
# [700]	train's rmse: 1.71361	valid's rmse: 2.16767
# [800]	train's rmse: 1.67162	valid's rmse: 2.16125
# [900]	train's rmse: 1.63491	valid's rmse: 2.15543
# [1000]	train's rmse: 1.60135	valid's rmse: 2.15255
# [1100]	train's rmse: 1.57068	valid's rmse: 2.14982
# [1200]	train's rmse: 1.54245	valid's rmse: 2.14807
# [1300]	train's rmse: 1.51638	valid's rmse: 2.14564
# [1400]	train's rmse: 1.49287	valid's rmse: 2.14321
# [1500]	train's rmse: 1.47079	valid's rmse: 2.14095
# [1600]	train's rmse: 1.44981	valid's rmse: 2.14038
# Early stopping, best iteration is:
# [1567]	train's rmse: 1.4567	valid's rmse: 2.14011
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.86823	valid's rmse: 3.14958
# [200]	train's rmse: 2.26316	valid's rmse: 2.55661
# [300]	train's rmse: 2.03106	valid's rmse: 2.36372
# [400]	train's rmse: 1.90328	valid's rmse: 2.2818
# [500]	train's rmse: 1.82101	valid's rmse: 2.24914
# [600]	train's rmse: 1.75887	valid's rmse: 2.23398
# [700]	train's rmse: 1.70958	valid's rmse: 2.22616
# [800]	train's rmse: 1.66763	valid's rmse: 2.22266
# [900]	train's rmse: 1.63082	valid's rmse: 2.21897
# [1000]	train's rmse: 1.59798	valid's rmse: 2.21654
# [1100]	train's rmse: 1.56788	valid's rmse: 2.21353
# [1200]	train's rmse: 1.53983	valid's rmse: 2.21174
# [1300]	train's rmse: 1.5144	valid's rmse: 2.21023
# Early stopping, best iteration is:
# [1316]	train's rmse: 1.51044	valid's rmse: 2.21004
# ================================================================================
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 2.92506	valid's rmse: 2.76866
# [200]	train's rmse: 2.29615	valid's rmse: 2.28802
# [300]	train's rmse: 2.05772	valid's rmse: 2.15609
# [400]	train's rmse: 1.9302	valid's rmse: 2.10203
# [500]	train's rmse: 1.84683	valid's rmse: 2.07937
# [600]	train's rmse: 1.7829	valid's rmse: 2.06621
# [700]	train's rmse: 1.73203	valid's rmse: 2.05855
# [800]	train's rmse: 1.68849	valid's rmse: 2.05366
# [900]	train's rmse: 1.64914	valid's rmse: 2.04994
# [1000]	train's rmse: 1.61505	valid's rmse: 2.04672
# [1100]	train's rmse: 1.58359	valid's rmse: 2.04415
# [1200]	train's rmse: 1.5546	valid's rmse: 2.04191
# [1300]	train's rmse: 1.52778	valid's rmse: 2.04018
# [1400]	train's rmse: 1.5035	valid's rmse: 2.03762
# [1500]	train's rmse: 1.48097	valid's rmse: 2.03636
# [1600]	train's rmse: 1.45949	valid's rmse: 2.03466
# [1700]	train's rmse: 1.43942	valid's rmse: 2.03319
# [1800]	train's rmse: 1.42052	valid's rmse: 2.03196
# [1900]	train's rmse: 1.40229	valid's rmse: 2.03077
# [2000]	train's rmse: 1.38548	valid's rmse: 2.0295
# [2100]	train's rmse: 1.36929	valid's rmse: 2.02871
# [2200]	train's rmse: 1.35396	valid's rmse: 2.02729
# [2300]	train's rmse: 1.33921	valid's rmse: 2.02605
# Early stopping, best iteration is:
# [2327]	train's rmse: 1.33546	valid's rmse: 2.0256
# ================================================================================
#
# Average CV : 2.1443435601154
# RMSE for OOF: 2.145546356662932
#
# Overall for OOF: 2.119065912759402
# RMSE for OOF: 2.1185499229857268

# %%
df_oof = pd.read_csv('../raw_dataset/train.csv', usecols = ['id','18~20_ride'])
df_oof['18~20_ride'] = outer_stractified_busroute_oof_train

# df_oof.to_csv('../oof/lgbm_5_seeds_stractified5k_bus_route_id_port.csv',index=False)
df_oof.to_csv('../lgbm_5_seeds_stractified5k_bus_route_id_port.csv',index=False)

df_sub = pd.read_csv('../raw_dataset/submission_sample.csv')
df_sub['18~20_ride'] = outer_stractified_busroute_oof_test

df_sub.to_csv('../submission/lgbm_5_seeds_stractified5k_bus_route_id_port.csv',index=False)

# %%
# StractifiedKfold & bus_route_id
split_col = 'bus_route_id'
len_seeds = 40

outer_stractified_busroute_oof_train = np.zeros( train.shape[0] )
outer_stractified_busroute_oof_test = np.zeros( test.shape[0] )

for _ in tqdm_notebook(range(len_seeds)):
    
    seed = random.randint(1, 100000)
    
    cv_list = []

    oof_train = np.zeros( train.shape[0] )
    final_test = np.zeros( test.shape[0] )

    kfolds = StratifiedKFold(n_splits = n_splits, shuffle=True, random_state=seed )

    for ind, (trn_ind, val_ind) in tqdm_notebook( enumerate(kfolds.split(train_set, train_set[split_col])) ):

        X_train, y_train = train_set.iloc[trn_ind], train_label[trn_ind]
        X_valid, y_valid = train_set.iloc[val_ind], train_label[val_ind]
        
        dtrain = lgbm.Dataset( X_train, y_train )
        dvalid = lgbm.Dataset( X_valid, y_valid ,reference=dtrain)
        
        lgbm_param['seed'] = seed

        model = lgbm.train(lgbm_param , dtrain, NUM_BOOST_ROUND, valid_sets=(dtrain, dvalid), valid_names=('train','valid'), 
                            categorical_feature=['bus_route_id','station_code','weekday',\
                                                                'kmeans1','kmeans2',
                                                                ] ,
                           verbose_eval= 100)

        valid_pred = model.predict(X_valid)
        test_pred  = model.predict(test_set)

        oof_train[val_ind] += valid_pred
        final_test += test_pred

        cv_list.append( sqrt(mean_squared_error(y_valid, valid_pred)) )

        print('='*80)

    final_test /= n_splits

    print(f"Average CV : {np.mean(cv_list)}")
    print(f"RMSE for OOF: {sqrt(mean_squared_error(train_label, oof_train))}")
    
    outer_stractified_busroute_oof_train += oof_train
    outer_stractified_busroute_oof_test += final_test
    
outer_stractified_busroute_oof_train /=len_seeds
outer_stractified_busroute_oof_test /= len_seeds

print(f"Overall for OOF: {sqrt(mean_squared_error(train_label, outer_stractified_busroute_oof_train))}")

# PostProcessing
outer_stractified_busroute_oof_train = [x if x>0 else 0 for x in  outer_stractified_busroute_oof_train]
outer_stractified_busroute_oof_test = [x if x>0 else 0 for x in  outer_stractified_busroute_oof_test]


print(f"RMSE for OOF: {sqrt(mean_squared_error(train_label, outer_stractified_busroute_oof_train))}")

# %%
df_oof = pd.read_csv('../raw_dataset/train.csv', usecols = ['id','18~20_ride'])
df_oof['18~20_ride'] = outer_stractified_busroute_oof_train

df_oof.to_csv('../oof/lgbm_40_seeds_stractified5k_bus_route_id.csv',index=False)

df_sub = pd.read_csv('../raw_dataset/submission_sample.csv')
df_sub['18~20_ride'] = outer_stractified_busroute_oof_test

df_sub.to_csv('../submission/lgbm_40_seeds_stractified5k_bus_route_id.csv',index=False)
